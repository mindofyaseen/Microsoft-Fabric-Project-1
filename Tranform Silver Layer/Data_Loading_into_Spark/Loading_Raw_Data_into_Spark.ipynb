# %% [markdown]
# # Data Engineering

# %% [markdown]
# ## Loading Raw Data

# %%
df = spark.read.format("csv").option("header","true").load("Files/Dumped Raw Data/AdventureWorks_Calendar.csv")
# df now is a Spark DataFrame containing CSV data from "Files/Dumped Raw Data/AdventureWorks_Calendar.csv".
display(df)
# Out:
# StatementMeta(, 5ec3dd48-b2c6-44ae-b669-757770ec8e21, 3, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, 076cde7b-a531-43f1-a097-1dd5114b9db1)

# %%
df = spark.read.format("csv").option("header","true").load("Files/Dumped Raw Data/AdventureWorks_Customers.csv")
# df now is a Spark DataFrame containing CSV data from "Files/Dumped Raw Data/AdventureWorks_Customers.csv".
display(df)
# Out:
# StatementMeta(, 5ec3dd48-b2c6-44ae-b669-757770ec8e21, 4, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, f2ed5a84-2f2e-4ffb-974c-f5f60b66ddb8)

# %%
df = spark.read.format("csv").option("header","true").load("Files/Dumped Raw Data/AdventureWorks_Product_Categories.csv")
# df now is a Spark DataFrame containing CSV data from "Files/Dumped Raw Data/AdventureWorks_Product_Categories.csv".
display(df)
# Out:
# StatementMeta(, 5ec3dd48-b2c6-44ae-b669-757770ec8e21, 5, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, e24de66b-5436-4bcd-8c30-28e7edb53909)

# %%
df = spark.read.format("csv").option("header","true").load("Files/Dumped Raw Data/AdventureWorks_Product_Subcategories.csv")
# df now is a Spark DataFrame containing CSV data from "Files/Dumped Raw Data/AdventureWorks_Product_Subcategories.csv".
display(df)
# Out:
# StatementMeta(, 5ec3dd48-b2c6-44ae-b669-757770ec8e21, 6, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, a62db1e6-90cc-4b8c-a8aa-c583b2c71e17)

# %%
df = spark.read.format("csv").option("header","true").load("Files/Dumped Raw Data/AdventureWorks_Products.csv")
# df now is a Spark DataFrame containing CSV data from "Files/Dumped Raw Data/AdventureWorks_Products.csv".
display(df)
# Out:
# StatementMeta(, 5ec3dd48-b2c6-44ae-b669-757770ec8e21, 7, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, 5ae28c5f-bbca-4b99-b84b-5d33951a759f)

# %%
df = spark.read.format("csv").option("header","true").load("Files/Dumped Raw Data/AdventureWorks_Returns.csv")
# df now is a Spark DataFrame containing CSV data from "Files/Dumped Raw Data/AdventureWorks_Returns.csv".
display(df)
# Out:
# StatementMeta(, 5ec3dd48-b2c6-44ae-b669-757770ec8e21, 8, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, dfe87d7a-165c-4490-852f-222f154ce85a)

# %%
df = spark.read.format("csv").option("header","true").load("Files/Dumped Raw Data/AdventureWorks_Returns.csv")
# df now is a Spark DataFrame containing CSV data from "Files/Dumped Raw Data/AdventureWorks_Returns.csv".
display(df)
# Out:
# StatementMeta(, 5ec3dd48-b2c6-44ae-b669-757770ec8e21, 9, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, 287f79ed-c0bb-48b5-8c76-6197d5ff5fe3)

# %%
df = spark.read.format("csv").option("header","true").load("Files/Dumped Raw Data/AdventureWorks_Territories.csv")
# df now is a Spark DataFrame containing CSV data from "Files/Dumped Raw Data/AdventureWorks_Territories.csv".
display(df)
# Out:
# StatementMeta(, 5ec3dd48-b2c6-44ae-b669-757770ec8e21, 10, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, ebeeb40d-7cf4-4350-8654-6e46c2b361f8)

# %% [markdown]
# ## Loading Transformed Data

# %%
df = spark.read.format("csv").option("header","true").load("Files/Transformation of DataFlowGen2/Customer_Demographic_Engineering.csv")
# df now is a Spark DataFrame containing CSV data from "Files/Transformation of DataFlowGen2/Customer_Demographic_Engineering.csv".
display(df)
# Out:
# StatementMeta(, 5ec3dd48-b2c6-44ae-b669-757770ec8e21, 11, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, fcc463fc-2246-4f23-a24e-9021cbc139cc)

# %%
df = spark.read.format("csv").option("header","true").load("Files/Transformation of DataFlowGen2/Fact_Sales.csv")
# df now is a Spark DataFrame containing CSV data from "Files/Transformation of DataFlowGen2/Fact_Sales.csv".
display(df)
# Out:
# StatementMeta(, 5ec3dd48-b2c6-44ae-b669-757770ec8e21, 12, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, b8b0b492-c0be-4738-926c-2a3771a70756)

# %%
df = spark.read.format("csv").option("header","true").load("Files/Transformation of DataFlowGen2/Flat_Product_Hierarchy.csv")
# df now is a Spark DataFrame containing CSV data from "Files/Transformation of DataFlowGen2/Flat_Product_Hierarchy.csv".
display(df)
# Out:
# StatementMeta(, 5ec3dd48-b2c6-44ae-b669-757770ec8e21, 13, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, 041a6281-7ec4-4aca-b825-2f01e4b09473)

# %%
df = spark.read.format("csv").option("header","true").load("Files/Transformation of DataFlowGen2/Product_Return_Rate_Analysis.csv")
# df now is a Spark DataFrame containing CSV data from "Files/Transformation of DataFlowGen2/Product_Return_Rate_Analysis.csv".
display(df)
# Out:
# StatementMeta(, 5ec3dd48-b2c6-44ae-b669-757770ec8e21, 14, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, 7aa4db5f-38bd-48c2-8a98-65015e2d0080)

# %%
df = spark.read.format("csv").option("header","true").load("Files/Transformation of DataFlowGen2/Time_Intelligence_Calendar.csv")
# df now is a Spark DataFrame containing CSV data from "Files/Transformation of DataFlowGen2/Time_Intelligence_Calendar.csv".
display(df)
# Out:
# StatementMeta(, 5ec3dd48-b2c6-44ae-b669-757770ec8e21, 15, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, 592264b3-abe6-4248-8ab1-c6f5ffaf053b)

# %%
df = spark.read.format("csv").option("header","true").load("Files/Transformation of DataFlowGen2/Value_Added_Sales_Metrics.csv")
# df now is a Spark DataFrame containing CSV data from "Files/Transformation of DataFlowGen2/Value_Added_Sales_Metrics.csv".
display(df)
# Out:
# StatementMeta(, 5ec3dd48-b2c6-44ae-b669-757770ec8e21, 16, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, 735c924b-9800-4d5d-a2c9-1e9943abd476)
